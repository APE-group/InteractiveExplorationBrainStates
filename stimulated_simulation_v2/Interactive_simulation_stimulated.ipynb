# %%
import utilities as GUI
import imp
imp.reload(GUI) # if something in utilites.py has changed, this reloads it and includes the changes.
GUI.interactive_GUI()
# Out:
# SEJveChjaGlsZHJlbj0oVkJveChjaGlsZHJlbj0oRmxvYXRTbGlkZXIodmFsdWU9MS4wLCBjb250aW51b3VzX3VwZGF0ZT1GYWxzZSwgZGVzY3JpcHRpb249dSdJIGZhY3RvcicsIG1heD0xLjXigKY=
# Output()
# <utilities.interactive_GUI instance at 0x7fa801a23710>
